# %% [markdown]
# ## NewsFeed API

# %% [markdown]
# The main use of News API is to search through every article published by various news sources and blogs.NewsAPI is used for this

# %% [markdown]
# News API is a simple, easy-to-use REST API that returns JSON search results for current and historic news articles published by over 80,000 worldwide sources.
# Search through hundreds of millions of articles in 14 languages from 55 countries.

# %% [markdown]
# Although each news API may have different functionalities, generally news APIs work by scraping relevant text from news websites, blogs and articles. A news API provides programmatic access to news articles from multiple news websites and parses it to extract the news data, text and metadata. This is then delivered in JSON format, which can be integrated into your applications, allowing you to easily stream data feed from news sources worldwide. Fundamental (or simple) news APIs can only scrape basic data like headlines, snippets, date of publishing of the article and the author's name. However, advanced news feed APIs utilize AI-based methods like Natural Language Processing (NLP) as well as Machine Learning (ML) to tag contextual meta-data to news articles. They can recognize categories, sentiments, topics, persons, dates, events, and more to help users discover news headlines and snippets relevant to their use-case

# %% [markdown]
# __pprint__ - The pprint module provides a capability to “pretty-print” arbitrary Python data structures in a well-formatted and more readable way!

# %%
import pprint
import requests 

api_key = 'b6a3e8fa18ad460bbd7c64c5f7c101f0'

# %% [markdown]
# NewsAPI offers three endpoints:
#
# - '/v2/top-headlines', for the most important headlines per country and category
#
# - '/v2/everything', for all the news articles from over 30,000 sources
#
# - '/v2/sources', for information on the various sources

# %%
# Define the endpoint
url = 'https://newsapi.org/v2/everything?'

# %%
# Specify the query and number of returns
parameters = {
    'q': 'Travelers Companies', # query phrase
    'pageSize': 10,  # maximum is 100
    'apiKey': api_key # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and pretty print it
response_json_trav = response.json()
pprint.pprint(response_json_trav)
# Out:
# {'articles': [{'author': None,
#                'content': 'July 21 (Reuters) - Property and casualty insurer '
#                           'Travelers Companies Inc (TRV.N) reported a nearly '
#                           '29% fall in quarterly profit on Thursday, hurt by '
#                           'higher catastrophe-related claims and lower retur… '
#                           '[+1899 chars]',
#                'description': 'Property and casualty insurer Travelers '
#                               'Companies Inc <a '
#                               'href="https://www.reuters.com/companies/TRV.N" '
#                               'target="_blank">(TRV.N)</a> reported a nearly '
#                               '29% fall in quarterly profit on Thursday, hurt '
#                               'by higher catastrophe-related claims and lower '
#                               'returns on its …',
#                'publishedAt': '2022-07-21T11:06:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'U.S. insurer Travelers posts plunge in profit as '
#                         'catastrophe claims mount - Reuters.com',
#                'url': 'https://www.reuters.com/markets/financials/us-insurer-travelers-posts-plunge-profit-catastrophe-claims-mount-2022-07-21/',
#                'urlToImage': 'https://www.reuters.com/resizer/VTkz-uvvKFVK6AV5YfZjwfW82d8=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/7LMHZIOXEFM6DD7NTJ7DEGTPEY.jpg'},
#               {'author': None,
#                'content': 'Aug 4 (Reuters) - Business jet maker Bombardier Inc '
#                           '(BBDb.TO) on Thursday reported a smaller '
#                           'second-quarter loss, helped by steady demand from '
#                           'wealthy travelers and lower interest expenses.\r\n'
#                           'Bombardi… [+1175 chars]',
#                'description': 'Business jet maker Bombardier Inc <a '
#                               'href="https://www.reuters.com/companies/BBDb.TO" '
#                               'target="_blank">(BBDb.TO)</a> on Thursday '
#                               'reported a smaller second-quarter loss, helped '
#                               'by steady demand from wealthy travelers and '
#                               'lower interest expenses.',
#                'publishedAt': '2022-08-04T10:34:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Bombardier reports smaller loss on steady demand for '
#                         'business jets - Reuters',
#                'url': 'https://www.reuters.com/business/aerospace-defense/bombardier-reports-smaller-loss-steady-demand-business-jets-2022-08-04/',
#                'urlToImage': 'https://www.reuters.com/resizer/MhG35VXrHnTu-_LmREwL9T-Kcx4=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/GD5JDYIJBRKC3ARM3DHHPTLVJ4.jpg'},
#               {'author': None,
#                'content': 'Aug 2 (Reuters) - Vacation rental Airbnb Inc '
#                           '(ABNB.O) on Tuesday forecast third-quarter revenue '
#                           'above estimates and announced a $2 billion share '
#                           'buyback, its first since going public, as '
#                           'pandemic-wea… [+1524 chars]',
#                'description': 'Vacation rental Airbnb Inc <a '
#                               'href="https://www.reuters.com/companies/ABNB.O" '
#                               'target="_blank">(ABNB.O)</a> on Tuesday '
#                               'forecast third-quarter revenue above estimates '
#                               'and announced a $2 billion share buyback, its '
#                               'first since going public, as pandemic-weary '
#                               'trav…',
#                'publishedAt': '2022-08-02T20:08:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Airbnb sees third-quarter revenue above estimates as '
#                         'summer bookings surge - Reuters',
#                'url': 'https://www.reuters.com/business/airbnb-sees-third-quarter-revenue-above-estimates-summer-bookings-surge-2022-08-02/',
#                'urlToImage': 'https://www.reuters.com/resizer/eDH71PyEXV4lvDREf3yixaof_bk=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/3TJ3QKIJTVNO7LVZFDXPCP2WSA.jpg'},
#               {'author': None,
#                'content': 'Aug 3 (Reuters) - Online travel agency Booking '
#                           'Holdings Inc (BKNG.O) posted an increase in '
#                           'quarterly revenue on Wednesday, as a surge in '
#                           'bookings amid a strong summer travel demand '
#                           'delivered a faster… [+836 chars]',
#                'description': 'Online travel agency Booking Holdings Inc <a '
#                               'href="https://www.reuters.com/companies/BKNG.O" '
#                               'target="_blank">(BKNG.O)</a> posted an increase '
#                               'in quarterly revenue on Wednesday, as a surge '
#                               'in bookings amid a strong summer travel demand '
#                               'delivered a faster-than-e…',
#                'publishedAt': '2022-08-03T20:20:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'Booking Holdings quarterly revenue rises on strong '
#                         'travel demand - Reuters',
#                'url': 'https://www.reuters.com/business/retail-consumer/booking-holdings-quarterly-revenue-rises-strong-travel-demand-2022-08-03/',
#                'urlToImage': 'https://www.reuters.com/resizer/AUaHr2zWZ75A1CEh9JDQH2cGeIQ=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/XMJTC7Z6IZJO5MIKPIMZNS5ASA.jpg'},
#               {'author': 'insider@insider.com (Meghan Hunter)',
#                'content': 'Personal Finance Insider writes about products, '
#                           'strategies, and tips to help you make smart '
#                           'decisions with your money. We may receive a small '
#                           'commission from our partners, like American '
#                           'Express, but … [+10601 chars]',
#                'description': 'The best travel insurance companies for seniors '
#                               'include Allianz, World Nomads, and Travel '
#                               'Guard. The best policy depends on what type of '
#                               'traveler you are.',
#                'publishedAt': '2022-07-21T18:43:51Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': 'The 7 best travel insurance companies for seniors in '
#                         '2022',
#                'url': 'https://www.businessinsider.com/personal-finance/best-travel-insurance-seniors',
#                'urlToImage': 'https://i.insider.com/62d99d95d0011000190fdc68?width=1200&format=jpeg'},
#               {'author': 'Danilo Diazgranados',
#                'content': 'Travel is back in a big way. With many countries '
#                           'loosening Covid restrictions and tourists regaining '
#                           'confidence in traveling again, industry numbers are '
#                           'poised to outpace even pre-pandemic levels. To… '
#                           '[+5555 chars]',
#                'description': "What this summer's trends reveal about where "
#                               'travelers are headed and why.',
#                'publishedAt': '2022-07-16T17:00:00Z',
#                'source': {'id': None, 'name': 'Entrepreneur'},
#                'title': 'Where Most Travelers Are Heading in Summer 2022 (and '
#                         'Why)',
#                'url': 'https://www.entrepreneur.com/article/429880',
#                'urlToImage': 'https://assets.entrepreneur.com/content/3x2/2000/1657638847-GettyImages-1166559157.jpg'},
#               {'author': 'kduffy@insider.com (Kate Duffy)',
#                'content': 'Airport delays are the result of passengers '
#                           'bringing more luggage and liquids through security, '
#                           "according to the CEO of one of Europe's busiest "
#                           'airports.\xa0\r\n'
#                           'Passengers traveling this summer from Londo… [+1878 '
#                           'chars]',
#                'description': 'Travelers are packing more liquids due to fears '
#                               'about losing their checked-in luggage, Heathrow '
#                               'Airport CEO John Holland-Kaye told LBC.',
#                'publishedAt': '2022-07-26T10:10:03Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': 'Airline passengers are causing delays by taking more '
#                         'bags and liquids through security, boss of one of '
#                         "Europe's busiest airport says",
#                'url': 'https://www.businessinsider.com/heathrow-airport-john-holland-kaye-ceo-blames-passengers-luggage-liquids-2022-7',
#                'urlToImage': 'https://i.insider.com/62dfb539bd18c30019d1cd5a?width=1200&format=jpeg'},
#               {'author': 'bnolan@insider.com (Beatrice Nolan)',
#                'content': 'Business travelers are catching the Eurostar train '
#                           'instead of gambling with chaotic airports and '
#                           'flight disruptions, new Eurostar data shared with '
#                           'Insider suggests.\r\n'
#                           "The rail operator's data shows th… [+1529 chars]",
#                'description': 'Eurostar data shows that corporate travel has '
#                               'increased to 70% of pre-COVID levels, despite '
#                               'the rail service only running 75% of its '
#                               'timetable.',
#                'publishedAt': '2022-07-18T11:58:48Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': 'Business travelers are ditching planes for Eurostar '
#                         'trains to avoid travel chaos and flight delays',
#                'url': 'https://www.businessinsider.com/travel-chaos-eurostar-planes-business-travelers-flight-delays-2022-7',
#                'urlToImage': 'https://i.insider.com/62d542d8aac2aa0018cb902f?width=1200&format=jpeg'},
#               {'author': 'insider@insider.com (Aly J. Yale)',
#                'content': 'Travel has started to bounce back after its steep '
#                           "pandemic decline. But that doesn't mean COVID-19 or "
#                           "other potential snags won't disrupt your travel "
#                           'plans.\r\n'
#                           'Fortunately, coverage is available that c… [+6290 '
#                           'chars]',
#                'description': 'Annual travel insurance is great for travelers '
#                               'who plan to take multiple trips in a year. It '
#                               'may cover baggage delays or missed connections.',
#                'publishedAt': '2022-07-20T20:53:55Z',
#                'source': {'id': 'business-insider', 'name': 'Business Insider'},
#                'title': 'Annual travel insurance plans protect frequent '
#                         'travelers under one umbrella policy',
#                'url': 'https://www.businessinsider.com/personal-finance/annual-travel-insurance',
#                'urlToImage': 'https://i.insider.com/62d6ce0fbc4c770018b7658e?width=1200&format=jpeg'},
#               {'author': 'Patrick McGeehan and Thomas Prior',
#                'content': 'The city is not exactly known for its '
#                           'state-of-the-art airports. That should change by '
#                           '2030.\r\n'
#                           'July 21, 2022Complaining about the sorry state of '
#                           'New York Citys airports has become a national '
#                           'pastime.\r'
#                           '… [+13972 chars]',
#                'description': 'The city is not exactly known for its '
#                               'state-of-the-art airports. That should change '
#                               'by 2030.',
#                'publishedAt': '2022-07-21T09:01:03Z',
#                'source': {'id': None, 'name': 'New York Times'},
#                'title': 'La Guardia, Kennedy and Newark Airports Get a $25 '
#                         'Billion Overhaul',
#                'url': 'https://www.nytimes.com/2022/07/21/nyregion/nyc-airports-renovation.html',
#                'urlToImage': 'https://static01.nyt.com/images/2022/05/31/nyregion/00airports-promo/00airports-promo-facebookJumbo-v4.jpg'}],
#  'status': 'ok',
#  'totalResults': 812}

# %%
# Specify the query and number of returns

parameters = {
    'q': 'Google', # query phrase
    'pageSize': 2,  # maximum is 100
    'apiKey': api_key # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Igor Bonifacic',
#                'content': 'Contrary to what you may have heard in the past few '
#                           'days, Google says its not shutting down its Stadia '
#                           'gaming service. The company issued the statement '
#                           'after a rumor began circulating earlier this we… '
#                           '[+2210 chars]',
#                'description': 'Contrary to what you may have heard in the past '
#                               'few days, Google says it’s not shutting down '
#                               'its Stadia gaming service. The company issued '
#                               'the statement after a rumor began circulating '
#                               'earlier this week that suggested it would '
#                               'sunset the platform later this y…',
#                'publishedAt': '2022-07-30T17:15:48Z',
#                'source': {'id': 'engadget', 'name': 'Engadget'},
#                'title': 'Google is not shutting Stadia down',
#                'url': 'https://www.engadget.com/google-denies-stadia-shutdown-rumor-171548840.html',
#                'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-11/47f78210-3c86-11ec-bfff-741576379f38'},
#               {'author': 'Boone Ashworth',
#                'content': 'Surprise, Googles got a new app. OK, youre probably '
#                           'not all that surprised. Google has always had an '
#                           'on-again, off-again relationship with the housemade '
#                           'apps that Android phones use to access its ser… '
#                           '[+4895 chars]',
#                'description': 'Plus: Samsung’s Galaxy Unpacked event returns, '
#                               'Amazon hoovers up some health care, and '
#                               'Facebook prizes growth above all else.',
#                'publishedAt': '2022-07-23T13:00:00Z',
#                'source': {'id': 'wired', 'name': 'Wired'},
#                'title': 'Google Wallet Is Back, for Some Reason',
#                'url': 'https://www.wired.com/story/google-wallet-samsung-unpacked-amazon-one-medical/',
#                'urlToImage': 'https://media.wired.com/photos/62db0d79b014c7f5985e3392/191:100/w_1280,c_limit/Google-Wallet-is-Back-Gear.jpg'}],
#  'status': 'ok',
#  'totalResults': 99130}

# %%
#all the news articles between the dates 2022-08-05 to 2022-08-08 sorted by popularity.

import pprint
import requests 

api_key = 'b6a3e8fa18ad460bbd7c64c5f7c101f0'

url = 'https://newsapi.org/v2/everything?'
parameters = {
    'q': 'TRV', # query phrase
    'from' :'2022-08-05',
    'to':'2022-08-08',
    'pageSize': 2,  # maximum is 100
    'sortBy':'popularity',
    'apiKey': api_key # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
#https://newsapi.org/v2/everything?q=apple&from=2022-08-07&to=2022-08-07&sortBy=popularity&apiKey=b6a3e8fa18ad460bbd7c64c5f7c101f0
# Out:
# {'articles': [{'author': 'MarketWatch Automation',
#                'content': 'The Dow Jones Industrial Average is trading up '
#                           'Friday afternoon with shares of JPMorgan Chase and '
#                           'Chevron seeing positive growth for the '
#                           'price-weighted average. The Dow \r\n'
#                           ' DJIA,\r\n'
#                           ' +0.04%\r\n'
#                           'is trading … [+703 chars]',
#                'description': 'The Dow Jones Industrial Average is trading up '
#                               'Friday afternoon with shares of JPMorgan Chase '
#                               'and Chevron seeing positive growth for the '
#                               'price-weighted...',
#                'publishedAt': '2022-08-05T17:21:46Z',
#                'source': {'id': None, 'name': 'MarketWatch'},
#                'title': 'Dow Update: JPMorgan Chase, Chevron share gains '
#                         "contribute to Dow's nearly 50-point climb",
#                'url': 'https://www.marketwatch.com/story/jpmorgan-chase-chevron-share-gains-contribute-to-dow-s-nearly-50-point-climb-01659719766',
#                'urlToImage': 'https://mw3.wsj.net/mw5/content/logos/mw_logo_social.png'},
#               {'author': 'Julius de Kempenaer',
#                'content': 'From time to time I compare the rotations of the '
#                           'SPDR sectors that we usually use with their EW '
#                           'counterparts.\r\n'
#                           'The first RRG below shows the rotations for the '
#                           'SPDR sector spiders (cap-weighted). The … [+5410 '
#                           'chars]',
#                'description': 'From time to time I compare the rotations of '
#                               'the SPDR sectors that we usually use with their '
#                               'EW counterparts.The first RRG below shows the '
#                               'rotations for the SPDR sector spiders '
#                               '(cap-weighted). The second RRG shows the '
#                               'rotations of the Equal Weight sectors. In…',
#                'publishedAt': '2022-08-05T19:00:35Z',
#                'source': {'id': None, 'name': 'Stockcharts.com'},
#                'title': 'Disconnected EW Sector Rotation Offers Opportunities',
#                'url': 'https://stockcharts.com/articles/rrg/2022/08/disconnected-ew-sector-rotatio-972.html',
#                'urlToImage': 'https://stockcharts.com/img/articles/2022/08/05/4a60fec0-4bc9-4628-88c3-568b45ac1e74.jpg'}],
#  'status': 'ok',
#  'totalResults': 2}

# %%
# all the news headlines (print just the titles).

for i in response_json['articles']:
    print(i['title'])
# Out:
# Google is not shutting Stadia down
# Google Wallet Is Back, for Some Reason

# %%
#Travelers Only Titles
for i in response_json_trav['articles']:
    print(i['title'])
# Out:
# U.S. insurer Travelers posts plunge in profit as catastrophe claims mount - Reuters.com
# Bombardier reports smaller loss on steady demand for business jets - Reuters
# Airbnb sees third-quarter revenue above estimates as summer bookings surge - Reuters
# Booking Holdings quarterly revenue rises on strong travel demand - Reuters
# The 7 best travel insurance companies for seniors in 2022
# Where Most Travelers Are Heading in Summer 2022 (and Why)
# Airline passengers are causing delays by taking more bags and liquids through security, boss of one of Europe's busiest airport says
# Business travelers are ditching planes for Eurostar trains to avoid travel chaos and flight delays
# Annual travel insurance plans protect frequent travelers under one umbrella policy
# La Guardia, Kennedy and Newark Airports Get a $25 Billion Overhaul
# U.S. cruise operators' recovery runs into rough weather as labor crisis worsens - Reuters
# Hong Kong Cuts COVID-19 Hotel Quarantine to 3 Days for Arrivals
# ECB's time to hike, Italy's time for more instability - Reuters.com
# Customers unable to navigate this summer's flight chaos online are getting stuck paying $25 fees to buy or change their tickets over the phone
# Outages at WestJet, NAV Canada cause delays at Canadian airports - Reuters.com
# Cancel for any reason travel insurance provides comprehensive coverage for your trip in case you can't go
# AirTags in baggage help travelers locate lost bags, but can’t solve airline incompetence
# NerdWallet: Three hidden travel fees to watch for
# Analysis: Aviation sector feels heat on emissions at air show - Reuters.com
# Biden says Senate bill will fight inflation and bring down cost of living.

# %%
## all the headlines together in one string

text_combined = ''
# Loop through all the headlines and add them to 'text_combined' 
for i in response_json['articles']:
    text_combined += i['title'] + ' ' # add a space after every headline, so the first and last words are not glued together
# Print the first 300 characters to screen for inspection
print(text_combined[0:300])
# Out:
# Google is not shutting Stadia down Google Wallet Is Back, for Some Reason

# %% [markdown]
# ## Headings

# %%
import requests

# Define the endpoint
url = 'https://newsapi.org/v2/top-headlines?'

# Specify the query and number of returns 
parameters = {
    'country':'us', # query phrase
    'pageSize': 2,  # maximum is 100
    'apiKey': api_key # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': None,
#                'content': 'Aug 8 (Reuters) - U.N. Secretary-General Antonio '
#                           'Guterres called on Monday for international '
#                           'inspectors to be given access to the Zaporizhzhia '
#                           'nuclear plant after Ukraine and Russia traded '
#                           'accusation… [+5361 chars]',
#                'description': 'U.N. Secretary-General Antonio Guterres called '
#                               'on Monday for international inspectors to be '
#                               'given access to the Zaporizhzhia nuclear plant '
#                               'after Ukraine and Russia traded accusations '
#                               "over the shelling of Europe's largest atomic "
#                               'plant at the weekend.',
#                'publishedAt': '2022-08-08T07:45:00Z',
#                'source': {'id': 'reuters', 'name': 'Reuters'},
#                'title': 'UN chief demands international access to Ukraine '
#                         'nuclear plant after new attack - Reuters',
#                'url': 'https://www.reuters.com/world/europe/un-chief-demands-international-access-ukraine-nuclear-plant-after-new-attack-2022-08-08/',
#                'urlToImage': 'https://www.reuters.com/resizer/IhEeDvDraukrUv_J8GA5aWrTPAA=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/JX5RIREEQ5INTNWHV4TC7QQKOA.jpg'},
#               {'author': 'Arjun Kharpal',
#                'content': 'SoftBank posted one of its biggest losses at its '
#                           'Vision Fund investment unit for its fiscal first '
#                           'quarter, as technology stocks continue to get '
#                           'hammered amid rising interest rates.\r\n'
#                           'The Japanese gian… [+1398 chars]',
#                'description': 'SoftBank posted a 2.93 trillion Japanese yen '
#                               '($21.68 billion) loss for the June quarter for '
#                               'its Vision Fund. This is its second-largest '
#                               'quarterly loss.',
#                'publishedAt': '2022-08-08T06:33:54Z',
#                'source': {'id': None, 'name': 'CNBC'},
#                'title': 'SoftBank posts a $21.6 billion quarterly loss on its '
#                         'Vision Fund, one of the highest in its history - CNBC',
#                'url': 'https://www.cnbc.com/2022/08/08/softbank-vision-fund-posts-a-21point6-billion-quarterly-loss-.html',
#                'urlToImage': 'https://image.cnbcfm.com/api/v1/image/107099532-1659696101822-gettyimages-1238288252-JAPAN_SOFTBANK.jpeg?v=1659696197&w=1920&h=1080'}],
#  'status': 'ok',
#  'totalResults': 38}

# %%
#top headines in India

import requests

# Define the endpoint
url = 'https://newsapi.org/v2/top-headlines?'

# Specify the query and number of returns 
parameters = {
    'country':'in', # query phrase
    'pageSize': 5 ,  # maximum is 100
    'apiKey': api_key # your own API key
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'articles': [{'author': 'Sports Desk',
#                'content': 'The star Indian badminton pair has been consistent '
#                           'with their performance in the ongoing games in '
#                           'Birmingham and now they have an opportunity to make '
#                           'it big with a gold medal here. They face a tough … '
#                           '[+1882 chars]',
#                'description': 'CWG 2022 Live score: Check Satwik Sairaj/Chirag '
#                               'Shetty vs Ben Lane/Sean Vendy Gold Medal Match '
#                               'Latest Updates in Men’s Doubles Badminton in '
#                               'Birmingham. The Indian ace duo starts as '
#                               'favourite against the English shuttlers.',
#                'publishedAt': '2022-08-08T12:21:16Z',
#                'source': {'id': None, 'name': 'News18'},
#                'title': "CWG 2022 Men's Doubles Badminton Final Highlights: "
#                         'Satwiksairaj Rankireddy-Chirag Shetty Clinch Gold '
#                         "After Beating England's Ben Lane-Sean Vendy - News18",
#                'url': 'https://www.news18.com/news/sports/satwik-sairaj-chirag-shetty-vs-ben-lane-sean-vendy-live-score-cwg-2022-gold-medal-match-badminton-mens-doubles-latest-updates-online-watch-streaming-livenews-5711041.html',
#                'urlToImage': 'https://images.news18.com/ibnlive/uploads/2022/08/cwg_083-165994906116x9.jpg'},
#               {'author': None,
#                'content': None,
#                'description': None,
#                'publishedAt': '2022-08-08T12:10:08Z',
#                'source': {'id': 'google-news', 'name': 'Google News'},
#                'title': 'India vs Australia Live Score, Hockey Final, '
#                         'Commonwealth Games 2022: Second half begins, India '
#                         'trails Australia 0-5 - Sportstar',
#                'url': 'https://news.google.com/__?oc=5',
#                'urlToImage': None},
#               {'author': 'Lisa Jennings',
#                'content': 'In October 2007, comet 17P/Holmes, otherwise '
#                           'spectacular, produced one of the most spectacular '
#                           'cometary flares ever observed. Remnants of the '
#                           'event can be seen by amateur telescopes in the '
#                           'northern h… [+3341 chars]',
#                'description': 'In October 2007, comet 17P/Holmes, otherwise '
#                               'spectacular, produced one of the most '
#                               'spectacular cometary flares ever observed. '
#                               'Remnants of the event can be',
#                'publishedAt': '2022-08-08T11:44:51Z',
#                'source': {'id': None, 'name': 'Bollyinside.com'},
#                'title': 'This month, sky watchers can see the debris from an '
#                         'impressive cometary outburst. - BollyInside',
#                'url': 'https://www.bollyinside.com/news/this-month-sky-watchers-can-see-the-debris-from-an-impressive-cometary-outburst',
#                'urlToImage': 'https://www.bollyinside.com/wp-content/uploads/2022/08/This-month-sky-watchers-can-see-the-debris-from-an.jpeg'},
#               {'author': 'Education and Careers Desk',
#                'content': 'Aug 08, 2022 17:02 ISTCHSE Odisha +2 Result: Arts '
#                           'Continues to Be Worst Performing Stream\r\n'
#                           'Stream-wise, once again, arts continues to be the '
#                           'worst performer in Class 12 Odisha results. As many '
#                           'as\xa082.… [+8459 chars]',
#                'description': 'CHSE Odisha +2 Results 2022 Declared! LIVE '
#                               'Updates: Students awaiting results can visit '
#                               'official websites, chse.nic.in, '
#                               'orissaresults.nic.in',
#                'publishedAt': '2022-08-08T11:32:25Z',
#                'source': {'id': None, 'name': 'News18'},
#                'title': 'CHSE Odisha +2 Arts Results Declared LIVE Updates: '
#                         '82.10% Students Pass, Girls Perform Better Than Boys '
#                         '- News18',
#                'url': 'https://www.news18.com/news/education-career/chse-odisha-plus-2-results-2022-live-updates-odisha-12th-arts-marksheet-at-chse-nic-in-meet-toppers-livenews-5710585.html',
#                'urlToImage': 'https://images.news18.com/ibnlive/uploads/2022/08/odisha12thartsresult-165994561216x9.jpg'},
#               {'author': 'DNA Web Team',
#                'content': 'Reported By:| Edited By: DNA Web Team |Source: DNA '
#                           'Web Desk |Updated: Aug 08, 2022, 04:50 PM ISTApple '
#                           'is gearing up to launch new flagship smartphones, '
#                           'Apple iPhone 14 series and till now we have see… '
#                           '[+1910 chars]',
#                'description': 'Gurman believes that the upcoming Apple event '
#                               'will be a virtual one and the company has '
#                               "'started to record' its September event.",
#                'publishedAt': '2022-08-08T11:17:00Z',
#                'source': {'id': None, 'name': 'DNA India'},
#                'title': 'Apple iPhone 14 launch date leaked, may arrive '
#                         'earlier than expected - DNA India',
#                'url': 'https://www.dnaindia.com/mobile/report-apple-iphone-14-launch-date-leaked-may-arrive-earlier-than-expected-2974911',
#                'urlToImage': 'https://cdn.dnaindia.com/sites/default/files/styles/half/public/2022/08/08/2528519-apple-iphone-14.png'}],
#  'status': 'ok',
#  'totalResults': 38}

# %% [markdown]
# ## Sources

# %%
import requests

# Define the endpoint
url = 'https://newsapi.org/v2/top-headlines/sources?'

# Specify the query and number of returns
parameters = {
    
    'apiKey': api_key # your own API key
    
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'sources': [{'category': 'general',
#               'country': 'us',
#               'description': 'Your trusted source for breaking news, analysis, '
#                              'exclusive interviews, headlines, and videos at '
#                              'ABCNews.com.',
#               'id': 'abc-news',
#               'language': 'en',
#               'name': 'ABC News',
#               'url': 'https://abcnews.go.com'},
#              {'category': 'general',
#               'country': 'au',
#               'description': "Australia's most trusted source of local, "
#                              'national and world news. Comprehensive, '
#                              'independent, in-depth analysis, the latest '
#                              'business, sport, weather and more.',
#               'id': 'abc-news-au',
#               'language': 'en',
#               'name': 'ABC News (AU)',
#               'url': 'http://www.abc.net.au/news'},
#              {'category': 'general',
#               'country': 'no',
#               'description': 'Norges ledende nettavis med alltid oppdaterte '
#                              'nyheter innenfor innenriks, utenriks, sport og '
#                              'kultur.',
#               'id': 'aftenposten',
#               'language': 'no',
#               'name': 'Aftenposten',
#               'url': 'https://www.aftenposten.no'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'News, analysis from the Middle East and '
#                              'worldwide, multimedia and interactives, '
#                              'opinions, documentaries, podcasts, long reads '
#                              'and broadcast schedule.',
#               'id': 'al-jazeera-english',
#               'language': 'en',
#               'name': 'Al Jazeera English',
#               'url': 'http://www.aljazeera.com'},
#              {'category': 'general',
#               'country': 'it',
#               'description': 'Agenzia ANSA: ultime notizie, foto, video e '
#                              'approfondimenti su: cronaca, politica, economia, '
#                              'regioni, mondo, sport, calcio, cultura e '
#                              'tecnologia.',
#               'id': 'ansa',
#               'language': 'it',
#               'name': 'ANSA.it',
#               'url': 'http://www.ansa.it'},
#              {'category': 'business',
#               'country': 'sa',
#               'description': 'ارقام موقع متخصص في متابعة سوق الأسهم السعودي '
#                              'تداول - تاسي - مع تغطيه معمقة لشركات واسعار '
#                              'ومنتجات البتروكيماويات , تقارير مالية الاكتتابات '
#                              'الجديده ',
#               'id': 'argaam',
#               'language': 'ar',
#               'name': 'Argaam',
#               'url': 'http://www.argaam.com'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': "The PC enthusiast's resource. Power users and "
#                              'the tools they love, without computing religion.',
#               'id': 'ars-technica',
#               'language': 'en',
#               'name': 'Ars Technica',
#               'url': 'http://arstechnica.com'},
#              {'category': 'general',
#               'country': 'pk',
#               'description': 'ARY News is a Pakistani news channel committed '
#                              'to bring you up-to-the minute Pakistan news and '
#                              'featured stories from around Pakistan and all '
#                              'over the world.',
#               'id': 'ary-news',
#               'language': 'ud',
#               'name': 'Ary News',
#               'url': 'https://arynews.tv/ud/'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'The AP delivers in-depth coverage on the '
#                              'international, politics, lifestyle, business, '
#                              'and entertainment news.',
#               'id': 'associated-press',
#               'language': 'en',
#               'name': 'Associated Press',
#               'url': 'https://apnews.com/'},
#              {'category': 'business',
#               'country': 'au',
#               'description': 'The Australian Financial Review reports the '
#                              'latest news from business, finance, investment '
#                              'and politics, updated in real time. It has a '
#                              'reputation for independent, award-winning '
#                              'journalism and is essential reading for the '
#                              'business and investor community.',
#               'id': 'australian-financial-review',
#               'language': 'en',
#               'name': 'Australian Financial Review',
#               'url': 'http://www.afr.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Axios are a new media company delivering vital, '
#                              'trustworthy news and analysis in the most '
#                              'efficient, illuminating and shareable ways '
#                              'possible.',
#               'id': 'axios',
#               'language': 'en',
#               'name': 'Axios',
#               'url': 'https://www.axios.com'},
#              {'category': 'general',
#               'country': 'gb',
#               'description': 'Use BBC News for up-to-the-minute news, breaking '
#                              'news, video, audio and feature stories. BBC News '
#                              'provides trusted World and UK news as well as '
#                              'local and regional perspectives. Also '
#                              'entertainment, business, science, technology and '
#                              'health news.',
#               'id': 'bbc-news',
#               'language': 'en',
#               'name': 'BBC News',
#               'url': 'http://www.bbc.co.uk/news'},
#              {'category': 'sports',
#               'country': 'gb',
#               'description': 'The home of BBC Sport online. Includes live '
#                              'sports coverage, breaking news, results, video, '
#                              'audio and analysis on Football, F1, Cricket, '
#                              'Rugby Union, Rugby League, Golf, Tennis and all '
#                              'the main world sports, plus major events such as '
#                              'the Olympic Games.',
#               'id': 'bbc-sport',
#               'language': 'en',
#               'name': 'BBC Sport',
#               'url': 'http://www.bbc.co.uk/sport'},
#              {'category': 'general',
#               'country': 'de',
#               'description': 'Die Seite 1 für aktuelle Nachrichten und Themen, '
#                              'Bilder und Videos aus den Bereichen News, '
#                              'Wirtschaft, Politik, Show, Sport, und Promis.',
#               'id': 'bild',
#               'language': 'de',
#               'name': 'Bild',
#               'url': 'http://www.bild.de'},
#              {'category': 'general',
#               'country': 'br',
#               'description': 'Descubra a seção brasileira da Blasting News, a '
#                              'primeira revista feita pelo  público, com '
#                              'notícias globais e vídeos independentes. '
#                              'Junte-se a nós e torne- se um repórter.',
#               'id': 'blasting-news-br',
#               'language': 'pt',
#               'name': 'Blasting News (BR)',
#               'url': 'https://br.blastingnews.com'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'Sports journalists and bloggers covering NFL, '
#                              'MLB, NBA, NHL, MMA, college football and '
#                              'basketball, NASCAR, fantasy sports and more. '
#                              'News, photos, mock drafts, game scores, player '
#                              'profiles and more!',
#               'id': 'bleacher-report',
#               'language': 'en',
#               'name': 'Bleacher Report',
#               'url': 'http://www.bleacherreport.com'},
#              {'category': 'business',
#               'country': 'us',
#               'description': 'Bloomberg delivers business and markets news, '
#                              'data, analysis, and video to the world, '
#                              'featuring stories from Businessweek and '
#                              'Bloomberg News.',
#               'id': 'bloomberg',
#               'language': 'en',
#               'name': 'Bloomberg',
#               'url': 'http://www.bloomberg.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Syndicated news and opinion website providing '
#                              'continuously updated headlines to top news and '
#                              'analysis sources.',
#               'id': 'breitbart-news',
#               'language': 'en',
#               'name': 'Breitbart News',
#               'url': 'http://www.breitbart.com'},
#              {'category': 'business',
#               'country': 'us',
#               'description': 'Business Insider is a fast-growing business site '
#                              'with deep financial, media, tech, and other '
#                              'industry verticals. Launched in 2007, the site '
#                              'is now the largest business news site on the '
#                              'web.',
#               'id': 'business-insider',
#               'language': 'en',
#               'name': 'Business Insider',
#               'url': 'http://www.businessinsider.com'},
#              {'category': 'business',
#               'country': 'gb',
#               'description': 'Business Insider is a fast-growing business site '
#                              'with deep financial, media, tech, and other '
#                              'industry verticals. Launched in 2007, the site '
#                              'is now the largest business news site on the '
#                              'web.',
#               'id': 'business-insider-uk',
#               'language': 'en',
#               'name': 'Business Insider (UK)',
#               'url': 'http://uk.businessinsider.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'BuzzFeed is a cross-platform, global network for '
#                              'news and entertainment that generates seven '
#                              'billion views each month.',
#               'id': 'buzzfeed',
#               'language': 'en',
#               'name': 'Buzzfeed',
#               'url': 'https://www.buzzfeed.com'},
#              {'category': 'general',
#               'country': 'ca',
#               'description': 'CBC News is the division of the Canadian '
#                              'Broadcasting Corporation responsible for the '
#                              'news gathering and production of news programs '
#                              "on the corporation's English-language "
#                              'operations, namely CBC Television, CBC Radio, '
#                              'CBC News Network, and CBC.ca.',
#               'id': 'cbc-news',
#               'language': 'en',
#               'name': 'CBC News',
#               'url': 'http://www.cbc.ca/news'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'CBS News: dedicated to providing the best in '
#                              'journalism under standards it pioneered at the '
#                              'dawn of radio and television and continue in the '
#                              'digital age.',
#               'id': 'cbs-news',
#               'language': 'en',
#               'name': 'CBS News',
#               'url': 'http://www.cbsnews.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'View the latest news and breaking news today for '
#                              'U.S., world, weather, entertainment, politics '
#                              'and health at CNN',
#               'id': 'cnn',
#               'language': 'en',
#               'name': 'CNN',
#               'url': 'http://us.cnn.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Lee las últimas noticias e información sobre '
#                              'Latinoamérica, Estados Unidos, mundo, '
#                              'entretenimiento, política, salud, tecnología y '
#                              'deportes en CNNEspañol.com.',
#               'id': 'cnn-es',
#               'language': 'es',
#               'name': 'CNN Spanish',
#               'url': 'http://cnnespanol.cnn.com/'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'Providing breaking cryptocurrency news - '
#                              'focusing on Bitcoin, Ethereum, ICOs, blockchain '
#                              'technology, and smart contracts.',
#               'id': 'crypto-coins-news',
#               'language': 'en',
#               'name': 'Crypto Coins News',
#               'url': 'https://www.ccn.com'},
#              {'category': 'general',
#               'country': 'de',
#               'description': 'Nachrichten, News und neueste Meldungen aus dem '
#                              'Inland und dem Ausland - aktuell präsentiert von '
#                              'tagesspiegel.de.',
#               'id': 'der-tagesspiegel',
#               'language': 'de',
#               'name': 'Der Tagesspiegel',
#               'url': 'http://www.tagesspiegel.de'},
#              {'category': 'business',
#               'country': 'de',
#               'description': 'Aktuelle Nachrichten, Kommentare, Analysen und '
#                              'Hintergrundberichte aus Politik, Wirtschaft, '
#                              'Gesellschaft, Wissen, Kultur und Sport lesen Sie '
#                              'auf ZEIT ONLINE.',
#               'id': 'die-zeit',
#               'language': 'de',
#               'name': 'Die Zeit',
#               'url': 'http://www.zeit.de/index'},
#              {'category': 'general',
#               'country': 'es',
#               'description': 'Noticias, actualidad, álbumes, debates, '
#                              'sociedad, servicios, entretenimiento y última '
#                              'hora en España y el mundo.',
#               'id': 'el-mundo',
#               'language': 'es',
#               'name': 'El Mundo',
#               'url': 'http://www.elmundo.es'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'Engadget is a web magazine with obsessive daily '
#                              'coverage of everything new in gadgets and '
#                              'consumer electronics.',
#               'id': 'engadget',
#               'language': 'en',
#               'name': 'Engadget',
#               'url': 'https://www.engadget.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Online version of the print magazine includes '
#                              'entertainment news, interviews, reviews of '
#                              'music, film, TV and books, and a special area '
#                              'for magazine subscribers.',
#               'id': 'entertainment-weekly',
#               'language': 'en',
#               'name': 'Entertainment Weekly',
#               'url': 'http://www.ew.com'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'ESPN has up-to-the-minute sports news coverage, '
#                              'scores, highlights and commentary for NFL, MLB, '
#                              'NBA, College Football, NCAA Basketball and more.',
#               'id': 'espn',
#               'language': 'en',
#               'name': 'ESPN',
#               'url': 'http://espn.go.com'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'ESPN Cricinfo provides the most comprehensive '
#                              'cricket coverage available including live '
#                              'ball-by-ball commentary, news, unparalleled '
#                              'statistics, quality editorial comment and '
#                              'analysis.',
#               'id': 'espn-cric-info',
#               'language': 'en',
#               'name': 'ESPN Cric Info',
#               'url': 'http://www.espncricinfo.com/'},
#              {'category': 'business',
#               'country': 'ca',
#               'description': 'Find the latest happenings in the Canadian '
#                              'Financial Sector and stay up to date with '
#                              'changing trends in Business Markets. Read '
#                              'trading and investing advice from professionals.',
#               'id': 'financial-post',
#               'language': 'en',
#               'name': 'Financial Post',
#               'url': 'http://business.financialpost.com'},
#              {'category': 'general',
#               'country': 'de',
#               'description': 'Minutenaktuelle Nachrichten und '
#                              'Service-Informationen von Deutschlands modernem '
#                              'Nachrichtenmagazin.',
#               'id': 'focus',
#               'language': 'de',
#               'name': 'Focus',
#               'url': 'http://www.focus.de'},
#              {'category': 'sports',
#               'country': 'it',
#               'description': 'Italian football news, analysis, fixtures and '
#                              'results for the latest from Serie A, Serie B and '
#                              'the Azzurri.',
#               'id': 'football-italia',
#               'language': 'en',
#               'name': 'Football Italia',
#               'url': 'http://www.football-italia.net'},
#              {'category': 'business',
#               'country': 'us',
#               'description': 'Fortune 500 Daily and Breaking Business News',
#               'id': 'fortune',
#               'language': 'en',
#               'name': 'Fortune',
#               'url': 'http://fortune.com'},
#              {'category': 'sports',
#               'country': 'gb',
#               'description': 'The latest football news, in-depth features, '
#                              'tactical and statistical analysis from '
#                              'FourFourTwo, the UK&#039;s favourite football '
#                              'monthly.',
#               'id': 'four-four-two',
#               'language': 'en',
#               'name': 'FourFourTwo',
#               'url': 'http://www.fourfourtwo.com/news'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Breaking News, Latest News and Current News from '
#                              'FOXNews.com. Breaking news and video. Latest '
#                              'Current News: U.S., World, Entertainment, '
#                              'Health, Business, Technology, Politics, Sports.',
#               'id': 'fox-news',
#               'language': 'en',
#               'name': 'Fox News',
#               'url': 'http://www.foxnews.com'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'Find live scores, player and team news, videos, '
#                              'rumors, stats, standings, schedules and fantasy '
#                              'games on FOX Sports.',
#               'id': 'fox-sports',
#               'language': 'en',
#               'name': 'Fox Sports',
#               'url': 'http://www.foxsports.com'},
#              {'category': 'general',
#               'country': 'br',
#               'description': 'Só na globo.com você encontra tudo sobre o '
#                              'conteúdo e marcas do Grupo Globo. O melhor '
#                              'acervo de vídeos online sobre entretenimento, '
#                              'esportes e jornalismo do Brasil.',
#               'id': 'globo',
#               'language': 'pt',
#               'name': 'Globo',
#               'url': 'http://www.globo.com/'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Comprehensive, up-to-date news coverage, '
#                              'aggregated from sources all over the world by '
#                              'Google News.',
#               'id': 'google-news',
#               'language': 'en',
#               'name': 'Google News',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'ar',
#               'description': 'Completa cobertura actualizada de noticias '
#                              'agregadas a partir de fuentes de todo el mundo '
#                              'por Google Noticias.',
#               'id': 'google-news-ar',
#               'language': 'es',
#               'name': 'Google News (Argentina)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'au',
#               'description': 'Comprehensive, up-to-date Australia news '
#                              'coverage, aggregated from sources all over the '
#                              'world by Google News.',
#               'id': 'google-news-au',
#               'language': 'en',
#               'name': 'Google News (Australia)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'br',
#               'description': 'Cobertura jornalística abrangente e atualizada, '
#                              'agregada de fontes do mundo inteiro pelo Google '
#                              'Notícias.',
#               'id': 'google-news-br',
#               'language': 'pt',
#               'name': 'Google News (Brasil)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'ca',
#               'description': 'Comprehensive, up-to-date Canada news coverage, '
#                              'aggregated from sources all over the world by '
#                              'Google News.',
#               'id': 'google-news-ca',
#               'language': 'en',
#               'name': 'Google News (Canada)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'fr',
#               'description': 'Informations complètes et à jour, compilées par '
#                              'Google Actualités à partir de sources '
#                              'd&#39;actualités du monde entier.',
#               'id': 'google-news-fr',
#               'language': 'fr',
#               'name': 'Google News (France)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'in',
#               'description': 'Comprehensive, up-to-date India news coverage, '
#                              'aggregated from sources all over the world by '
#                              'Google News.',
#               'id': 'google-news-in',
#               'language': 'en',
#               'name': 'Google News (India)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'is',
#               'description': 'כיסוי מקיף ועדכני של חדשות שהצטברו ממקורות בכל '
#                              'העולם על ידי &#39;חדשות Google&#39;.',
#               'id': 'google-news-is',
#               'language': 'he',
#               'name': 'Google News (Israel)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'it',
#               'description': 'Copertura giornalistica completa e aggiornata '
#                              'ottenuta combinando fonti di notizie in tutto il '
#                              'mondo attraverso Google News.',
#               'id': 'google-news-it',
#               'language': 'it',
#               'name': 'Google News (Italy)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'ru',
#               'description': 'Исчерпывающая и актуальная информация, собранная '
#                              'службой &quot;Новости Google&quot; со всего '
#                              'света.',
#               'id': 'google-news-ru',
#               'language': 'ru',
#               'name': 'Google News (Russia)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'sa',
#               'description': 'تغطية شاملة ومتجددة للأخبار، تم جمعها من مصادر '
#                              'أخبار من جميع أنحاء العالم بواسطة أخبار Google.',
#               'id': 'google-news-sa',
#               'language': 'ar',
#               'name': 'Google News (Saudi Arabia)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'gb',
#               'description': 'Comprehensive, up-to-date UK news coverage, '
#                              'aggregated from sources all over the world by '
#                              'Google News.',
#               'id': 'google-news-uk',
#               'language': 'en',
#               'name': 'Google News (UK)',
#               'url': 'https://news.google.com'},
#              {'category': 'general',
#               'country': 'se',
#               'description': 'Göteborgs-Posten, abbreviated GP, is a major '
#                              'Swedish language daily newspaper published in '
#                              'Gothenburg, Sweden.',
#               'id': 'goteborgs-posten',
#               'language': 'sv',
#               'name': 'Göteborgs-Posten',
#               'url': 'http://www.gp.se'},
#              {'category': 'technology',
#               'country': 'de',
#               'description': 'Online-Magazin für Startups und die digitale '
#                              'Wirtschaft. News und Hintergründe zu Investment, '
#                              'VC und Gründungen.',
#               'id': 'gruenderszene',
#               'language': 'de',
#               'name': 'Gruenderszene',
#               'url': 'http://www.gruenderszene.de'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'Hacker News is a social news website focusing on '
#                              'computer science and entrepreneurship. It is run '
#                              "by Paul Graham's investment fund and startup "
#                              'incubator, Y Combinator. In general, content '
#                              'that can be submitted is defined as "anything '
#                              'that gratifies one\'s intellectual curiosity".',
#               'id': 'hacker-news',
#               'language': 'en',
#               'name': 'Hacker News',
#               'url': 'https://news.ycombinator.com'},
#              {'category': 'business',
#               'country': 'de',
#               'description': 'Auf Handelsblatt lesen sie Nachrichten über '
#                              'Unternehmen, Finanzen, Politik und Technik. '
#                              'Verwalten Sie Ihre Finanzanlagen mit Hilfe '
#                              'unserer Börsenkurse.',
#               'id': 'handelsblatt',
#               'language': 'de',
#               'name': 'Handelsblatt',
#               'url': 'http://www.handelsblatt.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'IGN is your site for Xbox One, PS4, PC, Wii-U, '
#                              'Xbox 360, PS3, Wii, 3DS, PS Vita and iPhone '
#                              'games with expert reviews, news, previews, '
#                              'trailers, cheat codes, wiki guides and '
#                              'walkthroughs.',
#               'id': 'ign',
#               'language': 'en',
#               'name': 'IGN',
#               'url': 'http://www.ign.com'},
#              {'category': 'business',
#               'country': 'it',
#               'description': 'Notizie di economia, cronaca italiana ed estera, '
#                              'quotazioni borsa in tempo reale e di finanza, '
#                              'norme e tributi, fondi e obbligazioni, mutui, '
#                              'prestiti e lavoro a cura de Il Sole 24 Ore.',
#               'id': 'il-sole-24-ore',
#               'language': 'it',
#               'name': 'Il Sole 24 Ore',
#               'url': 'https://www.ilsole24ore.com'},
#              {'category': 'general',
#               'country': 'gb',
#               'description': 'National morning quality (tabloid) includes free '
#                              'online access to news and supplements. Insight '
#                              'by Robert Fisk and various other columnists.',
#               'id': 'independent',
#               'language': 'en',
#               'name': 'Independent',
#               'url': 'http://www.independent.co.uk'},
#              {'category': 'general',
#               'country': 'ar',
#               'description': 'Noticias de Argentina y del mundo en tiempo '
#                              'real. Información, videos y fotos sobre los '
#                              'hechos más relevantes y sus protagonistas. Léelo '
#                              'antes en infobae.',
#               'id': 'infobae',
#               'language': 'es',
#               'name': 'Infobae',
#               'url': 'http://www.infobae.com/?noredirect'},
#              {'category': 'business',
#               'country': 'br',
#               'description': 'No InfoMoney você encontra tudo o que precisa '
#                              'sobre dinheiro. Ações, investimentos, bolsas de '
#                              'valores e muito mais. Aqui você encontra '
#                              'informação que vale dinheiro!',
#               'id': 'info-money',
#               'language': 'pt',
#               'name': 'InfoMoney',
#               'url': 'https://www.infomoney.com.br'},
#              {'category': 'general',
#               'country': 'ar',
#               'description': 'El diario de Tucumán, noticias 24 horas online - '
#                              'San Miguel de Tucumán - Argentina - Ultimo '
#                              'momento - Ultimas noticias.',
#               'id': 'la-gaceta',
#               'language': 'es',
#               'name': 'La Gaceta',
#               'url': 'http://www.lagaceta.com.ar'},
#              {'category': 'general',
#               'country': 'ar',
#               'description': 'Información confiable en Internet. Noticias de '
#                              'Argentina y del mundo - ¡Informate ya!',
#               'id': 'la-nacion',
#               'language': 'es',
#               'name': 'La Nacion',
#               'url': 'http://www.lanacion.com.ar'},
#              {'category': 'general',
#               'country': 'it',
#               'description': 'Breaking News, Latest News and Current News from '
#                              'FOXNews.com. Breaking news and video. Latest '
#                              'Current News: U.S., World, Entertainment, '
#                              'Health, Business, Technology, Politics, Sports.',
#               'id': 'la-repubblica',
#               'language': 'it',
#               'name': 'La Repubblica',
#               'url': 'http://www.repubblica.it'},
#              {'category': 'general',
#               'country': 'fr',
#               'description': 'Les articles du journal et toute '
#                              "l'actualit&eacute; en continu : International, "
#                              'France, Soci&eacute;t&eacute;, Economie, '
#                              'Culture, Environnement, Blogs ...',
#               'id': 'le-monde',
#               'language': 'fr',
#               'name': 'Le Monde',
#               'url': 'http://www.lemonde.fr'},
#              {'category': 'general',
#               'country': 'ru',
#               'description': 'Новости, статьи, фотографии, видео. Семь дней в '
#                              'неделю, 24 часа в сутки.',
#               'id': 'lenta',
#               'language': 'ru',
#               'name': 'Lenta',
#               'url': 'https://lenta.ru'},
#              {'category': 'sports',
#               'country': 'fr',
#               'description': "Le sport en direct sur L'EQUIPE.fr. Les "
#                              'informations, résultats et classements de tous '
#                              'les sports. Directs commentés, images et vidéos '
#                              'à regarder et à partager !',
#               'id': 'lequipe',
#               'language': 'fr',
#               'name': "L'equipe",
#               'url': 'https://www.lequipe.fr'},
#              {'category': 'business',
#               'country': 'fr',
#               'description': "Toute l'actualité économique, financière et "
#                              'boursière française et internationale sur Les '
#                              'Echos.fr',
#               'id': 'les-echos',
#               'language': 'fr',
#               'name': 'Les Echos',
#               'url': 'https://www.lesechos.fr'},
#              {'category': 'general',
#               'country': 'fr',
#               'description': "Toute l'actualité en direct - photos et vidéos "
#                              'avec Libération',
#               'id': 'liberation',
#               'language': 'fr',
#               'name': 'Libération',
#               'url': 'http://www.liberation.fr'},
#              {'category': 'sports',
#               'country': 'es',
#               'description': 'La mejor información deportiva en castellano '
#                              'actualizada minuto a minuto en noticias, vídeos, '
#                              'fotos, retransmisiones y resultados en directo.',
#               'id': 'marca',
#               'language': 'es',
#               'name': 'Marca',
#               'url': 'http://www.marca.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Mashable is a global, multi-platform media and '
#                              'entertainment company.',
#               'id': 'mashable',
#               'language': 'en',
#               'name': 'Mashable',
#               'url': 'https://mashable.com'},
#              {'category': 'health',
#               'country': 'us',
#               'description': 'Medical news and health news headlines posted '
#                              'throughout the day, every day.',
#               'id': 'medical-news-today',
#               'language': 'en',
#               'name': 'Medical News Today',
#               'url': 'http://www.medicalnewstoday.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Breaking news and in-depth analysis of the '
#                              'headlines, as well as commentary and informed '
#                              'perspectives from The Rachel Maddow Show, '
#                              'Morning Joe & more.',
#               'id': 'msnbc',
#               'language': 'en',
#               'name': 'MSNBC',
#               'url': 'http://www.msnbc.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'The ultimate news source for music, celebrity, '
#                              'entertainment, movies, and current events on the '
#                              "web. It's pop culture on steroids.",
#               'id': 'mtv-news',
#               'language': 'en',
#               'name': 'MTV News',
#               'url': 'http://www.mtv.com/news'},
#              {'category': 'entertainment',
#               'country': 'gb',
#               'description': 'All the latest celebrity news, gossip, exclusive '
#                              'interviews and pictures from the world of music '
#                              'and entertainment.',
#               'id': 'mtv-news-uk',
#               'language': 'en',
#               'name': 'MTV News (UK)',
#               'url': 'http://www.mtv.co.uk/news'},
#              {'category': 'science',
#               'country': 'us',
#               'description': 'Reporting our world daily: original nature and '
#                              'science news from National Geographic.',
#               'id': 'national-geographic',
#               'language': 'en',
#               'name': 'National Geographic',
#               'url': 'http://news.nationalgeographic.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'National Review: Conservative News, Opinion, '
#                              'Politics, Policy, & Current Events.',
#               'id': 'national-review',
#               'language': 'en',
#               'name': 'National Review',
#               'url': 'https://www.nationalreview.com/'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Breaking news, videos, and the latest top '
#                              'stories in world news, business, politics, '
#                              'health and pop culture.',
#               'id': 'nbc-news',
#               'language': 'en',
#               'name': 'NBC News',
#               'url': 'http://www.nbcnews.com'},
#              {'category': 'general',
#               'country': 'za',
#               'description': "South Africa's premier news source, provides "
#                              'breaking news on national, world, Africa, sport, '
#                              'entertainment, technology and more.',
#               'id': 'news24',
#               'language': 'en',
#               'name': 'News24',
#               'url': 'http://www.news24.com'},
#              {'category': 'science',
#               'country': 'us',
#               'description': 'Breaking science and technology news from around '
#                              'the world. Exclusive stories and expert analysis '
#                              'on space, technology, health, physics, life and '
#                              'Earth.',
#               'id': 'new-scientist',
#               'language': 'en',
#               'name': 'New Scientist',
#               'url': 'https://www.newscientist.com/section/news'},
#              {'category': 'general',
#               'country': 'au',
#               'description': 'We say what people are thinking and cover the '
#                              'issues that get people talking balancing '
#                              'Australian and global moments — from politics to '
#                              'pop culture.',
#               'id': 'news-com-au',
#               'language': 'en',
#               'name': 'News.com.au',
#               'url': 'http://www.news.com.au'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Newsweek provides in-depth analysis, news and '
#                              'opinion about international issues, technology, '
#                              'business, culture and politics.',
#               'id': 'newsweek',
#               'language': 'en',
#               'name': 'Newsweek',
#               'url': 'https://www.newsweek.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'NYMAG and New York magazine cover the new, the '
#                              'undiscovered, the next in politics, culture, '
#                              'food, fashion, and behavior nationally, through '
#                              'a New York lens.',
#               'id': 'new-york-magazine',
#               'language': 'en',
#               'name': 'New York Magazine',
#               'url': 'http://nymag.com'},
#              {'category': 'science',
#               'country': 'us',
#               'description': 'Coverage of science and technology that have the '
#                              'potential for disruption, and analysis of plans, '
#                              'policies, and technology that enable radical '
#                              'improvement.',
#               'id': 'next-big-future',
#               'language': 'en',
#               'name': 'Next Big Future',
#               'url': 'https://www.nextbigfuture.com'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'The official source for NFL news, schedules, '
#                              'stats, scores and more.',
#               'id': 'nfl-news',
#               'language': 'en',
#               'name': 'NFL News',
#               'url': 'http://www.nfl.com/news'},
#              {'category': 'sports',
#               'country': 'us',
#               'description': 'The most up-to-date breaking hockey news from '
#                              'the official source including interviews, '
#                              'rumors, statistics and schedules.',
#               'id': 'nhl-news',
#               'language': 'en',
#               'name': 'NHL News',
#               'url': 'https://www.nhl.com/news'},
#              {'category': 'general',
#               'country': 'no',
#               'description': 'NRK er Norges største tilbud på nett: nyheter '
#                              'fra Norge og verden, lokalnyheter, radio- og '
#                              'tv-program, podcast, vær, helse-, kultur-, '
#                              'underholdning-, humor- og debattstoff.',
#               'id': 'nrk',
#               'language': 'no',
#               'name': 'NRK',
#               'url': 'https://www.nrk.no'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Political news about Congress, the White House, '
#                              'campaigns, lobbyists and issues.',
#               'id': 'politico',
#               'language': 'en',
#               'name': 'Politico',
#               'url': 'https://www.politico.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Polygon is a gaming website in partnership with '
#                              'Vox Media. Our culture focused site covers '
#                              'games, their creators, the fans, trending '
#                              'stories and entertainment news.',
#               'id': 'polygon',
#               'language': 'en',
#               'name': 'Polygon',
#               'url': 'http://www.polygon.com'},
#              {'category': 'general',
#               'country': 'ru',
#               'description': 'Главные новости политики, экономики и бизнеса, '
#                              'комментарии аналитиков, финансовые данные с '
#                              'российских и мировых биржевых систем на сайте '
#                              'rbc.ru.',
#               'id': 'rbc',
#               'language': 'ru',
#               'name': 'RBC',
#               'url': 'https://www.rbc.ru'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'Get the latest independent tech news, reviews '
#                              'and analysis from Recode with the most informed '
#                              'and respected journalists in technology and '
#                              'media.',
#               'id': 'recode',
#               'language': 'en',
#               'name': 'Recode',
#               'url': 'http://www.recode.net'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Reddit is an entertainment, social news '
#                              "networking service, and news website. Reddit's "
#                              'registered community members can submit content, '
#                              'such as text posts or direct links.',
#               'id': 'reddit-r-all',
#               'language': 'en',
#               'name': 'Reddit /r/all',
#               'url': 'https://www.reddit.com/r/all'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Reuters.com brings you the latest news from '
#                              'around the world, covering breaking news in '
#                              'business, politics, entertainment, technology, '
#                              'video and pictures.',
#               'id': 'reuters',
#               'language': 'en',
#               'name': 'Reuters',
#               'url': 'http://www.reuters.com'},
#              {'category': 'general',
#               'country': 'ru',
#               'description': 'Актуальная картина дня на RT: круглосуточное '
#                              'ежедневное обновление новостей политики, '
#                              'бизнеса, финансов, спорта, науки, культуры. '
#                              'Онлайн-репортажи с места событий. Комментарии '
#                              'экспертов, актуальные интервью, фото и видео '
#                              'репортажи.',
#               'id': 'rt',
#               'language': 'ru',
#               'name': 'RT',
#               'url': 'https://russian.rt.com'},
#              {'category': 'general',
#               'country': 'ie',
#               'description': 'Get all of the latest breaking local and '
#                              'international news stories as they happen, with '
#                              'up to the minute updates and analysis, from '
#                              "Ireland's National Broadcaster.",
#               'id': 'rte',
#               'language': 'en',
#               'name': 'RTE',
#               'url': 'https://www.rte.ie/news'},
#              {'category': 'general',
#               'country': 'nl',
#               'description': 'Volg het nieuws terwijl het gebeurt. RTL Nieuws '
#                              'informeert haar lezers op een onafhankelijke, '
#                              'boeiende en toegankelijke wijze over belangrijke '
#                              'ontwikkelingen in eigen land en de rest van de '
#                              'wereld.',
#               'id': 'rtl-nieuws',
#               'language': 'nl',
#               'name': 'RTL Nieuws',
#               'url': 'https://www.rtlnieuws.nl/'},
#              {'category': 'general',
#               'country': 'sa',
#               'description': 'صحيفة الكترونية سعودية هدفها السبق في نقل الحدث '
#                              'بمهنية ومصداقية خدمة للوطن والمواطن.',
#               'id': 'sabq',
#               'language': 'ar',
#               'name': 'SABQ',
#               'url': 'https://sabq.org'},
#              {'category': 'general',
#               'country': 'de',
#               'description': 'Deutschlands führende Nachrichtenseite. Alles '
#                              'Wichtige aus Politik, Wirtschaft, Sport, Kultur, '
#                              'Wissenschaft, Technik und mehr.',
#               'id': 'spiegel-online',
#               'language': 'de',
#               'name': 'Spiegel Online',
#               'url': 'http://www.spiegel.de'},
#              {'category': 'general',
#               'country': 'se',
#               'description': 'Sveriges ledande mediesajt - SvD.se. Svenska '
#                              'Dagbladets nyhetssajt låter läsarna ta plats och '
#                              'fördjupar nyheterna.',
#               'id': 'svenska-dagbladet',
#               'language': 'sv',
#               'name': 'Svenska Dagbladet',
#               'url': 'https://www.svd.se'},
#              {'category': 'technology',
#               'country': 'de',
#               'description': 'Das Online-Magazin bietet Artikel zu den Themen '
#                              'E-Business, Social Media, Startups und '
#                              'Webdesign.',
#               'id': 't3n',
#               'language': 'de',
#               'name': 'T3n',
#               'url': 'https://t3n.de'},
#              {'category': 'sports',
#               'country': 'gb',
#               'description': "Tune in to the world's biggest sports radio "
#                              'station - Live Premier League football coverage, '
#                              'breaking sports news, transfer rumours &amp; '
#                              'exclusive interviews.',
#               'id': 'talksport',
#               'language': 'en',
#               'name': 'TalkSport',
#               'url': 'http://talksport.com'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'TechCrunch is a leading technology media '
#                              'property, dedicated to obsessively profiling '
#                              'startups, reviewing new Internet products, and '
#                              'breaking tech news.',
#               'id': 'techcrunch',
#               'language': 'en',
#               'name': 'TechCrunch',
#               'url': 'https://techcrunch.com'},
#              {'category': 'technology',
#               'country': 'zh',
#               'description': 'TechCrunch is a leading technology media '
#                              'property, dedicated to obsessively profiling '
#                              'startups, reviewing new Internet products, and '
#                              'breaking tech news.',
#               'id': 'techcrunch-cn',
#               'language': 'zh',
#               'name': 'TechCrunch (CN)',
#               'url': 'https://techcrunch.cn'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'The latest technology news and reviews, covering '
#                              'computing, home entertainment systems, gadgets '
#                              'and more.',
#               'id': 'techradar',
#               'language': 'en',
#               'name': 'TechRadar',
#               'url': 'http://www.techradar.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Realism and reform. A new voice for a new '
#                              'generation of conservatives.',
#               'id': 'the-american-conservative',
#               'language': 'en',
#               'name': 'The American Conservative',
#               'url': 'http://www.theamericanconservative.com/'},
#              {'category': 'general',
#               'country': 'ca',
#               'description': 'The Globe and Mail offers the most authoritative '
#                              'news in Canada, featuring national and '
#                              'international news.',
#               'id': 'the-globe-and-mail',
#               'language': 'en',
#               'name': 'The Globe And Mail',
#               'url': 'https://www.theglobeandmail.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'The Hill is a top US political website, read by '
#                              'the White House and more lawmakers than any '
#                              'other site -- vital for policy, politics and '
#                              'election campaigns.',
#               'id': 'the-hill',
#               'language': 'en',
#               'name': 'The Hill',
#               'url': 'http://thehill.com'},
#              {'category': 'general',
#               'country': 'in',
#               'description': 'The Hindu. latest news, analysis, comment, '
#                              'in-depth coverage of politics, business, sport, '
#                              "environment, cinema and arts from India's "
#                              'national newspaper.',
#               'id': 'the-hindu',
#               'language': 'en',
#               'name': 'The Hindu',
#               'url': 'http://www.thehindu.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'The Huffington Post is a politically liberal '
#                              'American online news aggregator and blog that '
#                              'has both localized and international editions '
#                              'founded by Arianna Huffington, Kenneth Lerer, '
#                              'Andrew Breitbart, and Jonah Peretti, featuring '
#                              'columnists.',
#               'id': 'the-huffington-post',
#               'language': 'en',
#               'name': 'The Huffington Post',
#               'url': 'http://www.huffingtonpost.com'},
#              {'category': 'general',
#               'country': 'ie',
#               'description': 'The Irish Times online. Latest news including '
#                              'sport, analysis, business, weather and more from '
#                              'the definitive brand of quality news in Ireland.',
#               'id': 'the-irish-times',
#               'language': 'en',
#               'name': 'The Irish Times',
#               'url': 'https://www.irishtimes.com'},
#              {'category': 'general',
#               'country': 'is',
#               'description': 'The Jerusalem Post is the leading online '
#                              'newspaper for English speaking Jewry since 1932, '
#                              'bringing news and updates from the Middle East '
#                              'and all over the Jewish world.',
#               'id': 'the-jerusalem-post',
#               'language': 'en',
#               'name': 'The Jerusalem Post',
#               'url': 'https://www.jpost.com/'},
#              {'category': 'entertainment',
#               'country': 'gb',
#               'description': 'The LAD Bible is one of the largest community '
#                              'for guys aged 16-30 in the world. Send us your '
#                              'funniest pictures and videos!',
#               'id': 'the-lad-bible',
#               'language': 'en',
#               'name': 'The Lad Bible',
#               'url': 'https://www.theladbible.com'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'The Next Web is one of the world’s largest '
#                              'online publications that delivers an '
#                              'international perspective on the latest news '
#                              'about Internet technology, business and culture.',
#               'id': 'the-next-web',
#               'language': 'en',
#               'name': 'The Next Web',
#               'url': 'http://thenextweb.com'},
#              {'category': 'sports',
#               'country': 'gb',
#               'description': 'TheSPORTbible is one of the largest communities '
#                              'for sports fans across the world. Send us your '
#                              'sporting pictures and videos!',
#               'id': 'the-sport-bible',
#               'language': 'en',
#               'name': 'The Sport Bible',
#               'url': 'https://www.thesportbible.com'},
#              {'category': 'general',
#               'country': 'in',
#               'description': 'Times of India brings the Latest News and Top '
#                              'Breaking headlines on Politics and Current '
#                              'Affairs in India and around the World, Sports, '
#                              'Business, Bollywood News and Entertainment, '
#                              'Science, Technology, Health and Fitness news, '
#                              'Cricket and opinions from leading columnists.',
#               'id': 'the-times-of-india',
#               'language': 'en',
#               'name': 'The Times of India',
#               'url': 'http://timesofindia.indiatimes.com'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'The Verge covers the intersection of technology, '
#                              'science, art, and culture.',
#               'id': 'the-verge',
#               'language': 'en',
#               'name': 'The Verge',
#               'url': 'http://www.theverge.com'},
#              {'category': 'business',
#               'country': 'us',
#               'description': 'WSJ online coverage of breaking news and current '
#                              'headlines from the US and around the world. Top '
#                              'stories, photos, videos, detailed analysis and '
#                              'in-depth reporting.',
#               'id': 'the-wall-street-journal',
#               'language': 'en',
#               'name': 'The Wall Street Journal',
#               'url': 'http://www.wsj.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Breaking news and analysis on politics, '
#                              'business, world national news, entertainment '
#                              'more. In-depth DC, Virginia, Maryland news '
#                              'coverage including traffic, weather, crime, '
#                              'education, restaurant reviews and more.',
#               'id': 'the-washington-post',
#               'language': 'en',
#               'name': 'The Washington Post',
#               'url': 'https://www.washingtonpost.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'The Washington Times delivers breaking news and '
#                              'commentary on the issues that affect the future '
#                              'of our nation.',
#               'id': 'the-washington-times',
#               'language': 'en',
#               'name': 'The Washington Times',
#               'url': 'https://www.washingtontimes.com/'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Breaking news and analysis from TIME.com. '
#                              'Politics, world news, photos, video, tech '
#                              'reviews, health, science and entertainment news.',
#               'id': 'time',
#               'language': 'en',
#               'name': 'Time',
#               'url': 'http://time.com'},
#              {'category': 'general',
#               'country': 'us',
#               'description': 'Get the latest national, international, and '
#                              'political news at USATODAY.com.',
#               'id': 'usa-today',
#               'language': 'en',
#               'name': 'USA Today',
#               'url': 'http://www.usatoday.com/news'},
#              {'category': 'general',
#               'country': 'us',
#               'description': "Vice News is Vice Media, Inc.'s current affairs "
#                              'channel, producing daily documentary essays and '
#                              'video through its website and YouTube channel. '
#                              'It promotes itself on its coverage of "under - '
#                              'reported stories".',
#               'id': 'vice-news',
#               'language': 'en',
#               'name': 'Vice News',
#               'url': 'https://news.vice.com'},
#              {'category': 'technology',
#               'country': 'us',
#               'description': 'Wired is a monthly American magazine, published '
#                              'in print and online editions, that focuses on '
#                              'how emerging technologies affect culture, the '
#                              'economy, and politics.',
#               'id': 'wired',
#               'language': 'en',
#               'name': 'Wired',
#               'url': 'https://www.wired.com'},
#              {'category': 'technology',
#               'country': 'de',
#               'description': 'Wired reports on how emerging technologies '
#                              'affect culture, the economy and politics.',
#               'id': 'wired-de',
#               'language': 'de',
#               'name': 'Wired.de',
#               'url': 'https://www.wired.de'},
#              {'category': 'business',
#               'country': 'de',
#               'description': 'Das Online-Portal des führenden '
#                              'Wirtschaftsmagazins in Deutschland. Das '
#                              'Entscheidende zu Unternehmen, Finanzen, Erfolg '
#                              'und Technik.',
#               'id': 'wirtschafts-woche',
#               'language': 'de',
#               'name': 'Wirtschafts Woche',
#               'url': 'http://www.wiwo.de'},
#              {'category': 'general',
#               'country': 'zh',
#               'description': '中国主要重点新闻网站,依托新华社遍布全球的采编网络,记者遍布世界100多个国家和地区,地方频道分布全国31个省市自治区,每天24小时同时使用6种语言滚动发稿,权威、准确、及时播发国内外重要新闻和重大突发事件,受众覆盖200多个国家和地区,发展论坛是全球知名的中文论坛。',
#               'id': 'xinhua-net',
#               'language': 'zh',
#               'name': 'Xinhua Net',
#               'url': 'http://xinhuanet.com/'},
#              {'category': 'general',
#               'country': 'is',
#               'description': 'ynet דף הבית: אתר החדשות המוביל בישראל מבית '
#                              'ידיעות אחרונות. סיקור מלא של חדשות מישראל '
#                              'והעולם, ספורט, כלכלה, תרבות, אוכל, מדע וטבע, כל '
#                              'מה שקורה וכל מה שמעניין ב ynet.',
#               'id': 'ynet',
#               'language': 'he',
#               'name': 'Ynet',
#               'url': 'http://www.ynet.co.il'}],
#  'status': 'ok'}

# %%
import requests

# Define the endpoint
url = 'https://newsapi.org/v2/top-headlines/sources?'

# Specify the query and number of returns
parameters = {
   
    'category':'entertainment',
    'apiKey': api_key # your own API key
    
}

# Make the request
response = requests.get(url, params=parameters)

# Convert the response to JSON format and print it
response_json = response.json()
pprint.pprint(response_json)
# Out:
# {'sources': [{'category': 'entertainment',
#               'country': 'us',
#               'description': 'BuzzFeed is a cross-platform, global network for '
#                              'news and entertainment that generates seven '
#                              'billion views each month.',
#               'id': 'buzzfeed',
#               'language': 'en',
#               'name': 'Buzzfeed',
#               'url': 'https://www.buzzfeed.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Online version of the print magazine includes '
#                              'entertainment news, interviews, reviews of '
#                              'music, film, TV and books, and a special area '
#                              'for magazine subscribers.',
#               'id': 'entertainment-weekly',
#               'language': 'en',
#               'name': 'Entertainment Weekly',
#               'url': 'http://www.ew.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'IGN is your site for Xbox One, PS4, PC, Wii-U, '
#                              'Xbox 360, PS3, Wii, 3DS, PS Vita and iPhone '
#                              'games with expert reviews, news, previews, '
#                              'trailers, cheat codes, wiki guides and '
#                              'walkthroughs.',
#               'id': 'ign',
#               'language': 'en',
#               'name': 'IGN',
#               'url': 'http://www.ign.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Mashable is a global, multi-platform media and '
#                              'entertainment company.',
#               'id': 'mashable',
#               'language': 'en',
#               'name': 'Mashable',
#               'url': 'https://mashable.com'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'The ultimate news source for music, celebrity, '
#                              'entertainment, movies, and current events on the '
#                              "web. It's pop culture on steroids.",
#               'id': 'mtv-news',
#               'language': 'en',
#               'name': 'MTV News',
#               'url': 'http://www.mtv.com/news'},
#              {'category': 'entertainment',
#               'country': 'gb',
#               'description': 'All the latest celebrity news, gossip, exclusive '
#                              'interviews and pictures from the world of music '
#                              'and entertainment.',
#               'id': 'mtv-news-uk',
#               'language': 'en',
#               'name': 'MTV News (UK)',
#               'url': 'http://www.mtv.co.uk/news'},
#              {'category': 'entertainment',
#               'country': 'us',
#               'description': 'Polygon is a gaming website in partnership with '
#                              'Vox Media. Our culture focused site covers '
#                              'games, their creators, the fans, trending '
#                              'stories and entertainment news.',
#               'id': 'polygon',
#               'language': 'en',
#               'name': 'Polygon',
#               'url': 'http://www.polygon.com'},
#              {'category': 'entertainment',
#               'country': 'gb',
#               'description': 'The LAD Bible is one of the largest community '
#                              'for guys aged 16-30 in the world. Send us your '
#                              'funniest pictures and videos!',
#               'id': 'the-lad-bible',
#               'language': 'en',
#               'name': 'The Lad Bible',
#               'url': 'https://www.theladbible.com'}],
#  'status': 'ok'}

# %% [markdown]
# ### Social Media API - Twitter API - Tweepy

# %% [markdown]
# The API class provides access to the entire twitter RESTful API methods. Each method can accept various parameters and return responses

# %% [markdown]
# ### Using tweepy to Access Twitter Data
#
# To get started with the library, you need to install it through pip.
#
# pip install tweepy

# %% [markdown]
# - Your app's bearer token can be found under the Authentication Tokens section of the Keys and Tokens tab of your app, under the Twitter Developer Portal Projects & Apps page at https://developer.twitter.com/en/portal/projects-and-apps
#
# - Your app's API/consumer key and secret can be found under the Consumer Keys section of the Keys and Tokens tab of your app
#
# - Your account's (the app owner's account's) access token and secret for your app can be found under the Authentication Tokens section of the Keys and Tokens tab of your app
